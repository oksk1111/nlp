# %% [markdown]
# # 유클리드 거리 (Euclidean distance)
#
# 자카드 유사도, 코사인 유사도 만큼 유용한 방법은 아니다.<br>
# 두점 사이의 거리<br>
# 거리가 짧을수록 유사<br>
#
# $\sqrt{(q_{1}-p_{1})^{2}+(q_{2}-p_{2})^{2}+\ ...\ +(q_{n}-p_{n})^{2}}=\sqrt{\sum_{i=1}^{n}(q_{i}-p_{i})^{2}}$
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

def dist(x, y):
    return np.sqrt(np.sum((x-y)**2))

doc1 = np.array((2, 3, 0, 1))
doc2 = np.array((1, 2, 3, 1))
doc3 = np.array((2, 1, 2, 2))
docQ = np.array((1, 1, 0, 1))

print('dict doc1, doc1:', dist(doc1, docQ)) # 가장 가까움 = 유사
print('dict doc2, doc1:', dist(doc2, docQ))
print('dict doc3, doc1:', dist(doc3, docQ))
# Out:
# dict doc1, doc1: 2.23606797749979
# dict doc2, doc1: 3.1622776601683795
# dict doc3, doc1: 2.449489742783178

# %% [markdown]
# # 자카드 유사 (Jaccard similarity)
#
# 합집합에서 교집합의 비율을 구한다면 두 집합 A와 B의 유사도를 구할 수 있다는 아이디어.<br>
# 두 집한이 동일하다면 1, 공통원소가 없다면 0<br>
#
# $J(A,B)=\frac{|A∩B|}{|A∪B|}=\frac{|A∩B|}{|A|+|B|-|A∩B|}$
# <br><br>
# $J(doc_{1},doc_{2})=\frac{doc_{1}∩doc_{2}}{doc_{1}∪doc_{2}}$

# %%
doc1 = "apple banana everyone like likey watch card holder"
doc2 = "apple banana coupon passport love you"

# 토큰화
tokenized_doc1 = doc1.split()
tokenized_doc2 = doc2.split()

print('doc1:', tokenized_doc1)
print('doc2:', tokenized_doc2)
# Out:
# doc1: ['apple', 'banana', 'everyone', 'like', 'likey', 'watch', 'card', 'holder']
# doc2: ['apple', 'banana', 'coupon', 'passport', 'love', 'you']

# %%
# 합집합
union = set(tokenized_doc1).union(set(tokenized_doc2))
print('union:', union)

# 교집합
intersection = set(tokenized_doc1).intersection(set(tokenized_doc2))
print('intersection:', intersection)
# Out:
# union: {'holder', 'everyone', 'likey', 'watch', 'you', 'like', 'love', 'apple', 'passport', 'banana', 'coupon', 'card'}
# intersection: {'banana', 'apple'}

# %%
print('Jaccard sim:', len(intersection)/len(union))
# Out:
# Jaccard sim: 0.16666666666666666
