# %%
# !pip install konlpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 45.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.8/493.8 kB 21.4 MB/s eta 0:00:00
# ...

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from konlpy.tag import Okt

# %%
# NLTK에서 불용어 확인
stop_words_list = stopwords.words('english')
print('total count of stopwords:', len(stop_words_list))
print('sample of stopwords:', stop_words_list[:10])
# Out:
# total count of stopwords: 179
# sample of stopwords: ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
# 불용어 제거 - 영어
example = "Family is not an important thing. It's everything."
stop_words = set(stopwords.words('english')) # 중복 제거

word_tokens = word_tokenize(example)

result = []
for word in word_tokens:
    if word not in stop_words:
        result.append(word)

print("before stop_words:", word_tokens)
print("after stop_words:", result)
# Out:
# before stop_words: ['Family', 'is', 'not', 'an', 'important', 'thing', '.', 'It', "'s", 'everything', '.']
# after stop_words: ['Family', 'important', 'thing', '.', 'It', "'s", 'everything', '.']

# %% [markdown]
# # 불용어 제거 - 한글
#
# 아래의 링크는 보편적으로 선택할 수 있는 한국어 불용어 리스트. 절대적인 기준은 아님에 주의<br>
#
# 링크 : https://www.ranks.nl/stopwords/korean

# %%
# 불용어 제거 - 한글
#- 예시에서는 불용어를 임의 정의 후 사용
example = "고기를 아무렇게나 구우려고 하면 안 돼. 고기라고 다 같은 게 아니거든. 예컨대 삼겹살을 구울 때는 중요한 게 있지."

stop_words = "를 아무렇게나 구 우려 고 안 돼 같은 게 구울 때 는"
stop_words = set(stop_words.split(' '))

okt = Okt()
word_tokens = okt.morphs(example)

result = [word for word in word_tokens if not word in stop_words]

print("before stop_words:", word_tokens)
print("after stop_words:", result)
# Out:
# before stop_words: ['고기', '를', '아무렇게나', '구', '우려', '고', '하면', '안', '돼', '.', '고기', '라고', '다', '같은', '게', '아니거든', '.', '예컨대', '삼겹살', '을', '구울', '때', '는', '중요한', '게', '있지', '.']
# after stop_words: ['고기', '하면', '.', '고기', '라고', '다', '아니거든', '.', '예컨대', '삼겹살', '을', '중요한', '있지', '.']
