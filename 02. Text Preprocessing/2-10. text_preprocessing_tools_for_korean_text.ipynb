# %% [markdown]
# # PyKoSpacing
#
# 전희원님이 개발한 PyKoSpacing은 띄어쓰기가 되어있지 않은 문장을 띄어쓰기를 한 문장으로 변환해 주는 패키지. (대용량 코퍼스를 이용한 딥러닝 모델)

# %%
# !pip uninstall argparse
# Out:
# Found existing installation: argparse 1.4.0
# Uninstalling argparse-1.4.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/argparse-1.4.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/argparse.py
# Proceed (Y/n)? Y
#   Successfully uninstalled argparse-1.4.0

# %%
# !pip install argparse==1.4.0
# Out:
# ...
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# ...

# %%
# !pip install git+https://github.com/haven-jeon/PyKoSpacing.git
# Out:
# ...
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to /tmp/pip-req-build-w943zhhn
#   Running command git clone --filter=blob:none --quiet https://github.com/haven-jeon/PyKoSpacing.git /tmp/pip-req-build-w943zhhn
#   Resolved https://github.com/haven-jeon/PyKoSpacing.git to commit b32a889cbd10b006d2f4aba118f0cd5b677e2979
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# ...
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# ...
#   Created wheel for pykospacing: filename=pykospacing-0.5-py3-none-any.whl size=2286921 sha256=d219e70ee0ef9693fd0496cfce092071a1955c25d319f8f1120b0b5ea7222446
#   Stored in directory: /tmp/pip-ephem-wheel-cache-f84f3x08/wheels/76/b3/33/dda14886ee76b8e53eb05580a14dfcf9145e9eb9d282c53f28
# Successfully built pykospacing
# ...

# %%
sent = '김철수는 극중 두 인격의 사나이 이광수 역을 맡았다. 철수는 한국 유일의 태권도 전승자를 가리는 결전의 날을 앞두고 10년간 함께 훈련한 사형인 유연재(김광수 분)를 찾으러 속세로 내려온 인물이다.'

# %%
new_sent = sent.replace(" ", '') # 띄어쓰기가 없는 문장 임의로 만들기
print(new_sent)
# Out:
# 김철수는극중두인격의사나이이광수역을맡았다.철수는한국유일의태권도전승자를가리는결전의날을앞두고10년간함께훈련한사형인유연재(김광수분)를찾으러속세로내려온인물이다.

# %%
from pykospacing import Spacing
spacing = Spacing()
kospacing_sent = spacing(new_sent)

print(sent)
print(kospacing_sent) # 띄어쓰기 없는 문장을 띄어쓰기 있는 것으로 변경. 정상동작 확인
# Out:
# 김철수는 극중 두 인격의 사나이 이광수 역을 맡았다. 철수는 한국 유일의 태권도 전승자를 가리는 결전의 날을 앞두고 10년간 함께 훈련한 사형인 유연재(김광수 분)를 찾으러 속세로 내려온 인물이다.
# 김철수는 극중 두 인격의 사나이 이광수 역을 맡았다. 철수는 한국 유일의 태권도 전승자를 가리는 결전의 날을 앞두고 10년간 함께 훈련한 사형인 유연재(김광수 분)를 찾으러 속세로 내려온 인물이다.

# %% [markdown]
# # Py-Hnaspell
#
# (* 2024/03/03 이후 정상동작하지 않는다고 함)<br>
# Py-Hanspell은 네이버 한글 맞춤법 검사기를 바탕으로 만들어진 패키지.<br>
# 띄어쓰기도 보장

# %%
# !pip install git+https://github.com/ssut/py-hanspell.git
#!pip install git+https://github.com/kimsinn/py-hanspell.git
# Out:
# ...
#   Cloning https://github.com/ssut/py-hanspell.git to /tmp/pip-req-build-3i2qt5ey
#   Running command git clone --filter=blob:none --quiet https://github.com/ssut/py-hanspell.git /tmp/pip-req-build-3i2qt5ey
#   Resolved https://github.com/ssut/py-hanspell.git to commit fdc6ca50c19f1c85971437a072d89d4e5ce024b8
#   Preparing metadata (setup.py) ... done
# ...

# %%
from hanspell import spell_checker

sent = "맞춤법 틀리면 외 않되? 쓰고싶은대로쓰면돼지 "
spelled_sent = spell_checker.check(sent)

hanspell_sent = spelled_sent.checked
print(hanspell_sent)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-9f42d597179c> in <cell line: 4>()
#       2
#       3 sent = "맞춤법 틀리면 외 않되? 쓰고싶은대로쓰면돼지 "
# ----> 4 spelled_sent = spell_checker.check(sent)
#       5
#       6 hanspell_sent = spelled_sent.checked
#
# /usr/local/lib/python3.10/dist-packages/hanspell/spell_checker.py in check(text)
#      60
#      61     data = json.loads(r.text)
# ---> 62     html = data['message']['result']['html']
#      63     result = {
#      64         'result': True,
#
# KeyError: 'result'

# %%
spelled_sent = spell_checker.check(new_sent)

hanspell_sent = spelled_sent.checked
print(hanspell_sent)
print(kospacing_sent) # 앞서 사용한 kospacing 패키지에서 얻은 결과
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-fe9455f65023> in <cell line: 1>()
# ----> 1 spelled_sent = spell_checker.check(new_sent)
#       2
#       3 hanspell_sent = spelled_sent.checked
#       4 print(hanspell_sent)
#       5 print(kospacing_sent) # 앞서 사용한 kospacing 패키지에서 얻은 결과
#
# /usr/local/lib/python3.10/dist-packages/hanspell/spell_checker.py in check(text)
#      60
#      61     data = json.loads(r.text)
# ---> 62     html = data['message']['result']['html']
#      63     result = {
#      64         'result': True,
#
# KeyError: 'result'

# %% [markdown]
# # SOYNLP를 이용한 단어 토큰화
#
# soynlp는 품사 태깅, 단어 토큰화 등을 지원하는 단어 토크나이저.<br>
# 비지도 학습으로 단어 토큰화<br>
# 데이터에 자주 등장하는 단어들을 단어로 분석한다.

# %%
# !pip install soynlp
# !pip install konlpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 72.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.8/493.8 kB 29.4 MB/s eta 0:00:00
# ...

# %%
# soynlp 안 쓸 때
from konlpy.tag import Okt
tokenizer = Okt()
print(tokenizer.morphs('에이비식스 이대휘 1월 최애돌 기부 요정'))
# Out:
# ['에이', '비식스', '이대', '휘', '1월', '최애', '돌', '기부', '요정']

# %%
# soynlp 학습하기

import urllib.request
from soynlp import DoublespaceLineCorpus
from soynlp.word import WordExtractor

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/lovit/soynlp/master/tutorials/2016-10-20.txt", filename="2016-10-20.txt")
# Out:
# ('2016-10-20.txt', <http.client.HTTPMessage at 0x7b932bed3430>)

# %%
# 훈련 데이터를 다수의 문서로 분리
corpus = DoublespaceLineCorpus("2016-10-20.txt")
len(corpus)
# Out:
# 30091

# %%
# 상위 3개의 문서만 출력
i = 0
for document in corpus:
    if len(document) > 0:
        print(document)
        i = i + 1
    if i == 3:
        break
# Out:
# 19  1990  52 1 22
# ...

# %%
word_extractor = WordExtractor()
word_extractor.train(corpus) # 학습
word_score_table = word_extractor.extract()
# Out:
# training was done. used memory 1.660 Gb
# all cohesion probabilities was computed. # words = 223348
# all branching entropies was computed # words = 361598
# all accessor variety was computed # words = 361598

# %% [markdown]
# ## soynlp의 응집 확률 (cohension probability)
#
# 값이 클 수록 좋다.

# %%
word_score_table["반포한"].cohesion_forward
# Out:
# 0.08838002913645132

# %%
word_score_table["반포한강"].cohesion_forward
# Out:
# 0.19841268168224552

# %%
word_score_table["반포한강공"].cohesion_forward
# Out:
# 0.2972877884078849

# %%
word_score_table["반포한강공원"].cohesion_forward
# Out:
# 0.37891487632839754

# %%
word_score_table["반포한강공원에"].cohesion_forward
# Out:
# 0.33492963377557666

# %% [markdown]
# ## soynlp의 브랜칭 엔트로피 (branching entropy)
#
# 주어진 문자열에서 얼마나 다음 문자가 등장할 수 있는지를 판단하는 척도<br>

# %%
word_score_table['디스'].right_branching_entropy # 다음에 오는 문자를 헷갈릴수록 숫자가 높다
# Out:
# 1.6371694761537934

# %%
word_score_table['디스플'].right_branching_entropy
# Out:
# -0.0

# %%
word_score_table['디스플레이'].right_branching_entropy # 완전한 단어가 끝나면 또 헷갈릴 수 있다.
# Out:
# 3.1400392861792916

# %% [markdown]
# ## soynlp의 L tokenizer
#
# L / R 토큰으로 분리 (예: "공원에" -> "공원" + "에")

# %%
from soynlp.tokenizer import LTokenizer

scores = {word:score.cohesion_forward for word, score in word_score_table.items()}
l_tokenizer = LTokenizer(scores=scores)
l_tokenizer.tokenize("국제사회와 우리의 노력들로 범죄를 척결하자", flatten=False)
# Out:
# [('국제사회', '와'), ('우리', '의'), ('노력', '들로'), ('범죄', '를'), ('척결', '하자')]

# %% [markdown]
# ## 최대 점수 토크나이저
#
# 띄어쓰기가 되지 않는 문장에서 점수가 높은 글자 시퀀스를 순차적으로 찾아내는 토크나이저.

# %%
from soynlp.tokenizer import MaxScoreTokenizer

maxscore_tokenizer = MaxScoreTokenizer(scores=scores)
maxscore_tokenizer.tokenize("국제사회와우리의노력들로범죄를척결하자")
# Out:
# ['국제사회', '와', '우리', '의', '노력', '들로', '범죄', '를', '척결', '하자']

# %% [markdown]
# ## soynlp를 이용한 반복되는 문자 정제

# %%
from soynlp.normalizer import *

# %%
print(emoticon_normalize('앜ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', num_repeats=2))
print(emoticon_normalize('앜ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', num_repeats=2))
print(repeat_normalize('와하하하하하하하하하핫', num_repeats=2))
# Out:
# 아ㅋㅋ
# 아ㅋㅋ
# 와하하핫

# %% [markdown]
# ## customized KoNLPy
#
# 형태소 분석기를 이용한 단어 토큰화

# %%
# !pip install customized_konlpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.5/881.5 kB 10.0 MB/s eta 0:00:00
# ...

# %%
from ckonlpy.tag import Twitter
twitter = Twitter()
twitter.morphs("은경이는 사무실로 갔습니다.") # 형태소가 제대로 안나뉘는 경우 수동 튜닝 가능
# Out:
# /usr/local/lib/python3.10/dist-packages/konlpy/tag/_okt.py:17: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# ['은', '경이', '는', '사무실', '로', '갔습니다', '.']

# %%
twitter.add_dictionary("은경이", 'Noun')
twitter.morphs("은경이는 사무실로 갔습니다.")
# Out:
# ['은경이', '는', '사무실', '로', '갔습니다', '.']
